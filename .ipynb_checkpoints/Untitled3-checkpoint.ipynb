# %%
% matplotlib notebook

# %%
import matplotlib.pyplot as plt

import os
import pandas as pd
import numpy as np

# geo stuff
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns

gdf_2012 = gpd.GeoDataFrame.from_file('../data/2012/Data/3G/')

# %%
gdf_2012.plot()

# %%
plt.show()
